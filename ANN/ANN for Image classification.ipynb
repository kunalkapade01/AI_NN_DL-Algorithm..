# %% [markdown]
# # 𝐀𝐍𝐍 𝐟𝐨𝐫 𝐈𝐦𝐚𝐠𝐞 𝐜𝐥𝐚𝐬𝐬𝐢𝐟𝐢𝐜𝐚𝐭𝐢𝐨𝐧 :-

# %%
# Import library :
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.utils import to_categorical
# Out:
# WARNING:tensorflow:From C:\Users\kunal\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
import keras
from keras.datasets import cifar10

# %%
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# %%
x_train.shape
# Out:
# (50000, 32, 32, 3)

# %%
x_train[0]
# Out:
# array([[[ 59,  62,  63],
#         [ 43,  46,  45],
#         [ 50,  48,  43],
#         ...,
#         [158, 132, 108],
#         [152, 125, 102],
#         [148, 124, 103]],
#
#        [[ 16,  20,  20],
#         [  0,   0,   0],
#         [ 18,   8,   0],
#         ...,
#         [123,  88,  55],
#         [119,  83,  50],
#         [122,  87,  57]],
#
#        [[ 25,  24,  21],
#         [ 16,   7,   0],
#         [ 49,  27,   8],
#         ...,
#         [118,  84,  50],
#         [120,  84,  50],
#         [109,  73,  42]],
#
#        ...,
#
#        [[208, 170,  96],
#         [201, 153,  34],
#         [198, 161,  26],
#         ...,
#         [160, 133,  70],
#         [ 56,  31,   7],
#         [ 53,  34,  20]],
#
#        [[180, 139,  96],
#         [173, 123,  42],
#         [186, 144,  30],
#         ...,
#         [184, 148,  94],
#         [ 97,  62,  34],
#         [ 83,  53,  34]],
#
#        [[177, 144, 116],
#         [168, 129,  94],
#         [179, 142,  87],
# ...

# %%
#import requests
#import ssl

# Bypass SSL certificate verification
#ssl._create_default_https_context = ssl._create_unverified_context

# Now, try to fetch the URL
#response = requests.get("https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz")

# Continue with your code

# %%
import matplotlib.pyplot as plt
plt.imshow(x_train[0])
plt.show()

# %%
y_train[0]
# Out:
# array([6], dtype=uint8)

# %%
plt.imshow(x_train[3245])
plt.show()

# %%
y_train[3245]
# Out:
# array([2], dtype=uint8)

# %%
plt.imshow(x_train[4523])
plt.show()

# %%
y_train[32456]
# Out:
# array([2], dtype=uint8)

# %%
x_train = x_train/255.0
x_test = x_test/255.0

# %%
x_train[0]
# Out:
# array([[[0.23137255, 0.24313725, 0.24705882],
#         [0.16862745, 0.18039216, 0.17647059],
#         [0.19607843, 0.18823529, 0.16862745],
#         ...,
#         [0.61960784, 0.51764706, 0.42352941],
#         [0.59607843, 0.49019608, 0.4       ],
#         [0.58039216, 0.48627451, 0.40392157]],
#
#        [[0.0627451 , 0.07843137, 0.07843137],
#         [0.        , 0.        , 0.        ],
#         [0.07058824, 0.03137255, 0.        ],
#         ...,
#         [0.48235294, 0.34509804, 0.21568627],
#         [0.46666667, 0.3254902 , 0.19607843],
#         [0.47843137, 0.34117647, 0.22352941]],
#
#        [[0.09803922, 0.09411765, 0.08235294],
#         [0.0627451 , 0.02745098, 0.        ],
#         [0.19215686, 0.10588235, 0.03137255],
#         ...,
#         [0.4627451 , 0.32941176, 0.19607843],
#         [0.47058824, 0.32941176, 0.19607843],
#         [0.42745098, 0.28627451, 0.16470588]],
#
#        ...,
#
#        [[0.81568627, 0.66666667, 0.37647059],
# ...

# %%
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# %%
model = Sequential([
    Flatten(input_shape=(32,32,3)),
    Dense(512, activation="relu"),
    Dense(256, activation="relu"),
    Dense(10, activation="softmax")
])
# Out:
# WARNING:tensorflow:From C:\Users\kunal\anaconda3\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])
# Out:
# WARNING:tensorflow:From C:\Users\kunal\anaconda3\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
model.fit(x_train, y_train, epochs=30, batch_size=128, validation_data=(x_test, y_test))
# Out:
# Epoch 1/30
# WARNING:tensorflow:From C:\Users\kunal\anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\kunal\anaconda3\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 391/391 [==============================] - 16s 36ms/step - loss: 1.9128 - accuracy: 0.3163 - val_loss: 1.7546 - val_accuracy: 0.3639
# Epoch 2/30
# 391/391 [==============================] - 16s 40ms/step - loss: 1.6933 - accuracy: 0.3930 - val_loss: 1.6471 - val_accuracy: 0.4187
# Epoch 3/30
# 391/391 [==============================] - 16s 42ms/step - loss: 1.5994 - accuracy: 0.4319 - val_loss: 1.5995 - val_accuracy: 0.4314
# Epoch 4/30
# ...

# %%
from tensorflow.keras.preprocessing import image

# %%
Image_path = r"C:\Users\kunal\PycharmProjects\3RI_Data Analytics_Science\AI_DL_NN\ANN\airoplane_ANN.jpg"

# %%
Image = image.load_img(Image_path, target_size=(32,32))

# %%
Image_arr = image.img_to_array(Image)

# %%
Image_arr = np.expand_dims(Image_arr, axis=0)

# %%
prediction = model.predict(Image_arr)
# Out:
# 1/1 [==============================] - 0s 30ms/step

# %%
np.argmax(prediction)
# Out:
# 9
